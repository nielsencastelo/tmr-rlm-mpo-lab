# %%
from qa_nonrag.eval import main

if __name__ == "__main__": 
    main()
# Out:
# === q1 ===
# Pergunta: Qual é a janela de contexto do Phi-4 no catálogo descrito?
# Gold: 16k tokens ['DOC_PHI4#p1']
# Proposed: {'em': 0.0, 'f1': 0.13333333333333336, 'cite_precision': 1.0, 'cite_recall': 1.0} {'wall_ms': 96373.9404296875, 'prompt_tokens': 1966, 'output_tokens': 932}
# Context stuffing: {'em': 1.0, 'f1': 0.09756097560975609, 'cite_precision': 1.0, 'cite_recall': 1.0}
# Simple RAG: {'em': 1.0, 'f1': 0.09756097560975609, 'cite_precision': 1.0, 'cite_recall': 1.0}
#
# === q2 ===
# Pergunta: Quais campos de contagem de tokens a API /api/chat retorna segundo o documento?
# Gold: prompt_eval_count e eval_count ['DOC_OLLAMA_API#p0']
# Proposed: {'em': 1.0, 'f1': 0.375, 'cite_precision': 1.0, 'cite_recall': 1.0} {'wall_ms': 74533.8955078125, 'prompt_tokens': 2332, 'output_tokens': 721}
# Context stuffing: {'em': 1.0, 'f1': 0.07058823529411765, 'cite_precision': 1.0, 'cite_recall': 1.0}
# Simple RAG: {'em': 1.0, 'f1': 0.0625, 'cite_precision': 1.0, 'cite_recall': 1.0}
#
# ...
